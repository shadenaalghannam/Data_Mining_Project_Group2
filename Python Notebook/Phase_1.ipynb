# %% [markdown]
# **Project Goal**
#
# ---
#
#
# The goal of this project is to analyze water quality
# data using classification and clustering techniques.
#
# For the classification task, the objective is to predict whether a water sample is potable or non-potable based on its physical and chemical characteristics.
#
# For the clustering task, the objective is to group water samples with similar water quality characteristics and identify patterns within the dataset.
# <br><br>
#
#
#
#
# **Dataset Source**
#
# ---
#
# The data set used in this project was obtained from Kaggle under the title "Water Quality and Portability".<br>
# URL: https://www.kaggle.com/datasets/uom190346a/water-quality-and-potability?resource=download
# <br><br>
#
# **Dataset Description**
#
# ---
# The following section provides general information about the dataset, including the number of records, attributes, data types, class values, and the number of instances in each class

# %%
import pandas as pd
df = pd.read_csv("Raw_dataset.csv")

# %%
print("Number of records:", df.shape[0])
print("Number of attributes:", df.shape[1])
# Out:
# Number of records: 3276
# Number of attributes: 10

# %%
print("\nColumn Names:")
print(df.columns.tolist())
# Out:
# Column Names:
# ['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity', 'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability']

# %%
print("\nAttributes and Data Types:")
print(df.dtypes)
# Out:
# Attributes and Data Types:
# ph                 float64
# Hardness           float64
# Solids             float64
# Chloramines        float64
# Sulfate            float64
# Conductivity       float64
# Organic_carbon     float64
# Trihalomethanes    float64
# Turbidity          float64
# Potability           int64
# dtype: object

# %%
print("\nClass Attribute: Potability")
print("Class Values: 0 = Non-potable, 1 = Potable")
# Out:
# Class Attribute: Potability
# Class Values: 0 = Non-potable, 1 = Potable

# %%
print("\nNumber of Classes:", df["Potability"].nunique())
# Out:
# Number of Classes: 2

# %%
print("\nNumber of Instances for Each Class:")
print(df["Potability"].value_counts())
# Out:
# Number of Instances for Each Class:
# Potability
# 0    1998
# 1    1278
# Name: count, dtype: int64

# %%
print("\nSample of the Raw Dataset:")
display(df.head())
# Out:
# Sample of the Raw Dataset:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0
